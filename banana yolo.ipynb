# %%
# !banana init hello-world
# Out:
# ⏰ Downloading boilerplate...
# 🌎 Creating virtual environment...
# 📦 Downloading packages...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 MB 5.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 14.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 6.9 MB/s eta 0:00:00
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# ...
#   Using cached redis-4.5.5-py3-none-any.whl (240 kB)
# ...
#   Using cached filelock-3.12.0-py3-none-any.whl (10 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 14.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 10.5 MB/s eta 0:00:00
# ...
#   Using cached numpy-1.24.3-cp311-cp311-macosx_10_9_x86_64.whl (19.8 MB)
# ...
